# %% [markdown]
# # Example 6: Electron Cooling

# %% [markdown]
# In this example, we will show how to use the electron cooling module, found in [*darkhistory.elec.elec_cooling*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/darkhistory.electrons.elec_cooling.html). This module takes an injected electron with some initial energy, and cools it completely through inverse Compton scattering (ICS) as well as ionization, excitation (both on HI, HeI and HeII) as well as Coulomb heating of free electrons.

# %% [markdown]
# ## Initialization

# %% [markdown]
# Let's load the stuff that we need. The function of interest is [*get_elec_cooling_tf()*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/elec_cooling/darkhistory.electrons.elec_cooling.get_elec_cooling_tf.html).
#
# We have also imported the default binning for photons and electrons used throughout DarkHistory using [*config.load_data()*](https://darkhistory.readthedocs.io/en/master/_autosummary/config/config.load_data.html).

# %%
# %load_ext autoreload
import sys
sys.path.append("..")

# %%
# %matplotlib inline
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:280: MatplotlibDeprecationWarning:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   import matplotlib

# %%
# %autoreload

import matplotlib
matplotlib.rc_file('matplotlibrc')
import matplotlib.pyplot as plt

import numpy as np

from config import load_data
import darkhistory.physics as phys
from darkhistory.electrons.elec_cooling import get_elec_cooling_tf

photeng = load_data('binning')['phot']
eleceng = load_data('binning')['elec']

# %% [markdown]
# ## Electron Cooling Function: [*get_elec_cooling_tf()*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/elec_cooling/darkhistory.electrons.elec_cooling.get_elec_cooling_tf.html)

# %% [markdown]
# The user should refer to the online documentation for details on how to use [*get_elec_cooling_tf()*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/electrons/elec_cooling/darkhistory.electrons.elec_cooling.get_elec_cooling_tf.html). In the simplest default case, we just need to give the function the electron and photon abscissae of interest, the redshift, and the ionization levels of hydrogen and helium.
#
# If we do not specify any ICS transfer functions to the function, DarkHistory automatically loads the required transfer functions from the downloaded data. If this is the first time the transfer functions are loaded, the successful completion of the import would look like this:
#
# ```
# ****** Loading transfer functions... ******
#     for inverse Compton (Thomson)...  Done!
#     for inverse Compton (relativistic)...  Done!
#     for inverse Compton (energy loss)...  Done!
# ****** Loading complete! ******
# ```

# %%
rs = 600
# This function returns the baseline value of xHII. 
xHII  = phys.xHII_std(rs)

elec_cooling_info = get_elec_cooling_tf(
    eleceng, photeng, rs, xHII, check_conservation_eng=True, verbose=True
)
# Out:
# ****** Loading transfer functions... ******
#     for inverse Compton (Thomson)...  Done!
#     for inverse Compton (relativistic)...  Done!
#     for inverse Compton (energy loss)...  Done!
# ****** Loading complete! ******
# ***************************************************
# rs:  600
# injected energy:  1.029782576544676
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.0920351523673162
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.1580510305357166
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.2280577107449062
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.3022964457049966
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.3810230721719563
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.464508892793674
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.5530416112742387
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.6469263233011588
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.7464865684742108
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.8520654450403526
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1.9640267921495251
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.0827564439969137
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.2086635591695085
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.34218203072669
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.483771981613245
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.633921350177843
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.7931475715595298
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2.9619993612286635
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.14105860539712
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.3309423667378724
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.5323050105944276
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.74584046023665
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3.9722845879150555
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4.2124177510268055
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4.4670674814260565
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4.737111336668022
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.023479924944695
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.32716011145385
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.649198419589084
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5.990704637486488
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6.3528556420933455
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  6.7368994553689845
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  7.144159544724971
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  7.576039384061005
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  8.03402729035588
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  8.519701552519109
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  9.03473587037297
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  9.580905122566037
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  10.160091482975986
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  10.774290907022078
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  11.42562000977341
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  12.116323360300157
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  12.848781216773205
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  13.625517729029525
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  14.44920963718323
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  15.32269549620105
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  16.24898545764154
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  17.23127164330799
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  18.27293914562324
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  19.377577693143394
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  20.548994021199178
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  21.791224990563933
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  23.108551498909947
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  24.5055132334237
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  25.986924315046053
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  27.557889888819773
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  29.223823716747575
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  30.990466834511608
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  32.86390733567532
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  34.85060135216918
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  36.957395303063095
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  39.19154948822688
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  41.56076310825301
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  44.07320079696365
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  46.73752075800439
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  49.56290460197488
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  52.55908898770576
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  55.73639917600667
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  59.105784611951094
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  62.678856658109
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  66.46792860905407
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  70.48605812445749
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  74.74709222768433
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  79.26571502455045
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  84.05749830661807
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  89.1389552137698
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  94.52759714098647
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  100.24199408461573
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  106.30183863738785
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  112.72801385167986
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  119.54266520531382
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  126.76927691808669
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  134.43275288149016
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  142.55950248084264
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  151.17753160570282
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  160.3165391620132
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  170.0080194186885
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  180.28537054092158
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  191.18400968506467
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  202.74149505078094
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  214.99765531200683
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  227.99472687160596
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  241.77749941428192
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  256.3934702575207
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  271.8930080339778
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  288.3295262688189
# Fraction of Energy in low energy electrons:  1.0
# Fraction of Energy in photons - Continuum:  0.0
# Fraction Deposited in ionization:  0.0
# Fraction Deposited in excitation:  0.0
# Fraction Deposited in heating:  0.0
# Energy is conserved up to (%):  0.0
# Fraction Deposited in ICS (Numerical Error):  0.0
# Energy conservation with deposited (%):  0.0
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  305.7596674498054
# ...
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1321320093607.8591
# Fraction of Energy in low energy electrons:  7.98228512827485e-09
# Fraction of Energy in photons - Continuum:  0.9999999868652197
# Fraction Deposited in ionization:  2.8940864193456576e-09
# Fraction Deposited in excitation:  2.2150854873707556e-09
# Fraction Deposited in heating:  5.783396075321127e-11
# Energy is conserved up to (%):  -1.4510837855510385e-09
# Fraction Deposited in ICS (Numerical Error):  -1.451074344109145e-11
# Energy conservation with deposited (%):  -9.441441893654131e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1401196740564.3086
# Fraction of Energy in low energy electrons:  7.527246836621355e-09
# Fraction of Energy in photons - Continuum:  0.9999999876139813
# Fraction Deposited in ionization:  2.729106076123918e-09
# Fraction Deposited in excitation:  2.0888122836650675e-09
# Fraction Deposited in heating:  5.453708084806458e-11
# Energy is conserved up to (%):  -1.3683636684734583e-09
# Fraction Deposited in ICS (Numerical Error):  -1.3683577849438964e-11
# Energy conservation with deposited (%):  -5.8835295620239864e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1485902102954.5662
# Fraction of Energy in low energy electrons:  7.09814846612369e-09
# Fraction of Energy in photons - Continuum:  0.9999999883200591
# Fraction Deposited in ionization:  2.5735306053578185e-09
# Fraction Deposited in excitation:  1.9697374125135824e-09
# Fraction Deposited in heating:  5.142814258215615e-11
# Energy is conserved up to (%):  -1.2903754906841427e-09
# Fraction Deposited in ICS (Numerical Error):  -1.2903499888003755e-11
# Energy conservation with deposited (%):  -2.5501883767161144e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1575728087031.9531
# Fraction of Energy in low energy electrons:  6.693511285163149e-09
# Fraction of Energy in photons - Continuum:  0.9999999889858858
# Fraction Deposited in ionization:  2.426823872716546e-09
# Fraction Deposited in excitation:  1.857450525639369e-09
# Fraction Deposited in heating:  4.849643228127404e-11
# Energy is conserved up to (%):  -1.2167856676036475e-09
# Fraction Deposited in ICS (Numerical Error):  -1.216773227852122e-11
# Energy conservation with deposited (%):  -1.2439751525511396e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1670984245411.8242
# Fraction of Energy in low energy electrons:  6.311940858722776e-09
# Fraction of Energy in photons - Continuum:  0.9999999896998072
# Fraction Deposited in ionization:  2.288480306752789e-09
# Fraction Deposited in excitation:  1.7515646670869067e-09
# Fraction Deposited in heating:  4.573184714344868e-11
# Energy is conserved up to (%):  -9.752488465127856e-09
# Fraction Deposited in ICS (Numerical Error):  -9.752477422452155e-11
# Energy conservation with deposited (%):  -1.1042675701177066e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1771998843832.1865
# Fraction of Energy in low energy electrons:  5.952122242973574e-09
# Fraction of Energy in photons - Continuum:  0.9999999902130003
# Fraction Deposited in ionization:  2.1580231566343563e-09
# Fraction Deposited in excitation:  1.6517149397189132e-09
# Fraction Deposited in heating:  4.312486001988074e-11
# Energy is conserved up to (%):  -1.7985765074997215e-09
# Fraction Deposited in ICS (Numerical Error):  -1.798553846052794e-11
# Energy conservation with deposited (%):  -2.2661446927285537e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1879119992402.2852
# Fraction of Energy in low energy electrons:  5.612815453798421e-09
# Fraction of Energy in photons - Continuum:  0.999999990770394
# Fraction Deposited in ionization:  2.03500284919568e-09
# Fraction Deposited in excitation:  1.5575572477309533e-09
# Fraction Deposited in heating:  4.0666486576775044e-11
# Energy is conserved up to (%):  -1.6436102714213e-09
# Fraction Deposited in ICS (Numerical Error):  -1.643612850692511e-11
# Energy conservation with deposited (%):  2.5792712109541075e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  1992716845237.605
# Fraction of Energy in low energy electrons:  5.292851193637371e-09
# Fraction of Energy in photons - Continuum:  0.9999999912961413
# Fraction Deposited in ionization:  1.918995439647257e-09
# Fraction Deposited in excitation:  1.4687671108502848e-09
# Fraction Deposited in heating:  3.834825475747666e-11
# Energy is conserved up to (%):  -1.5103297898822717e-09
# Fraction Deposited in ICS (Numerical Error):  -1.5103189828593958e-11
# Energy conservation with deposited (%):  -1.0807022875883777e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2113180872615.4043
# Fraction of Energy in low energy electrons:  4.991126821928537e-09
# Fraction of Energy in photons - Continuum:  1.0000000082047413
# Fraction Deposited in ionization:  1.8096011506040021e-09
# Fraction Deposited in excitation:  1.385038546132527e-09
# Fraction Deposited in heating:  3.616217601653669e-11
# Energy is conserved up to (%):  -1.6426669990281077e-06
# Fraction Deposited in ICS (Numerical Error):  -1.6426669934592423e-08
# Energy conservation with deposited (%):  -5.56886528983243e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2240927210034.778
# Fraction of Energy in low energy electrons:  4.706602555258096e-09
# Fraction of Energy in photons - Continuum:  0.9999999934932018
# Fraction Deposited in ionization:  1.706442994397775e-09
# Fraction Deposited in excitation:  1.3060830135026453e-09
# Fraction Deposited in heating:  3.410071715133776e-11
# Energy is conserved up to (%):  -1.246431072194121e-07
# Fraction Deposited in ICS (Numerical Error):  -1.2464311487758876e-09
# Energy conservation with deposited (%):  7.658176642471038e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2376396088830.3022
# Fraction of Energy in low energy electrons:  4.438297884124462e-09
# Fraction of Energy in photons - Continuum:  0.9999999937799647
# Fraction Deposited in ionization:  1.60916547392631e-09
# Fraction Deposited in excitation:  1.2316284214063727e-09
# Fraction Deposited in heating:  3.215677394155158e-11
# Energy is conserved up to (%):  -1.0912134828045774e-07
# Fraction Deposited in ICS (Numerical Error):  -1.0912131691516345e-09
# Energy conservation with deposited (%):  -3.136529426928132e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2520054353269.385
# Fraction of Energy in low energy electrons:  4.185288193968518e-09
# Fraction of Energy in photons - Continuum:  0.9999999940650404
# Fraction Deposited in ionization:  1.51743335756161e-09
# Fraction Deposited in excitation:  1.1614181891455196e-09
# Fraction Deposited in heating:  3.0323646728050367e-11
# Energy is conserved up to (%):  -9.595041565542088e-08
# Fraction Deposited in ICS (Numerical Error):  -9.59504035312503e-10
# Energy conservation with deposited (%):  -1.2124170572590595e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2672397069361.388
# Fraction of Energy in low energy electrons:  3.946701578825522e-09
# Fraction of Energy in photons - Continuum:  1.0000008691822002
# Fraction Deposited in ionization:  1.430930523895951e-09
# Fraction Deposited in excitation:  1.0952103626658326e-09
# Fraction Deposited in heating:  2.859501827766291e-11
# Energy is conserved up to (%):  -8.756836376371155e-05
# Fraction Deposited in ICS (Numerical Error):  -8.756836375411333e-07
# Energy conservation with deposited (%):  -9.598219446313565e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  2833949230922.7637
# Fraction of Energy in low energy electrons:  3.7217158366181787e-09
# Fraction of Energy in photons - Continuum:  1.000000054043603
# Fraction Deposited in ionization:  1.349358872344405e-09
# Fraction Deposited in excitation:  1.0327767807503475e-09
# Fraction Deposited in heating:  2.6964932216938207e-11
# Energy is conserved up to (%):  -6.01744191006208e-06
# Fraction Deposited in ICS (Numerical Error):  -6.017441906819007e-08
# Energy conservation with deposited (%):  -3.2430720459033744e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3005267568777.472
# Fraction of Energy in low energy electrons:  3.509555635735845e-09
# Fraction of Energy in photons - Continuum:  1.0000000471928003
# Fraction Deposited in ionization:  1.272437295849439e-09
# Fraction Deposited in excitation:  9.739022887446095e-10
# Fraction Deposited in heating:  2.5427771362044907e-11
# Energy is conserved up to (%):  -5.29741233056058e-06
# Fraction Deposited in ICS (Numerical Error):  -5.2974123412677295e-08
# Energy conservation with deposited (%):  1.0707149713873846e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3186942469327.463
# Fraction of Energy in low energy electrons:  3.309489843135779e-09
# Fraction of Energy in photons - Continuum:  1.0000000412765646
# Fraction Deposited in ionization:  1.1999007121475518e-09
# Fraction Deposited in excitation:  9.183839971042991e-10
# Fraction Deposited in heating:  2.397823787018181e-11
# Energy is conserved up to (%):  -4.672831738558614e-06
# Fraction Deposited in ICS (Numerical Error):  -4.6728317189909735e-08
# Energy conservation with deposited (%):  -1.956764014777991e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3379600009104.9067
# Fraction of Energy in low energy electrons:  3.1208290047587175e-09
# Fraction of Energy in photons - Continuum:  1.000000037162807
# Fraction Deposited in ionization:  1.1314991502595467e-09
# Fraction Deposited in excitation:  8.660305822101226e-10
# Fraction Deposited in heating:  2.2611335668400846e-11
# Energy is conserved up to (%):  -4.2303777088192945e-06
# Fraction Deposited in ICS (Numerical Error):  -4.2303777123254416e-08
# Energy conservation with deposited (%):  3.5061460927953076e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3583904112317.4634
# Fraction of Energy in low energy electrons:  2.942922969576096e-09
# Fraction of Energy in photons - Continuum:  1.0000000336036863
# Fraction Deposited in ionization:  1.0669968890564352e-09
# Fraction Deposited in excitation:  8.166616270405226e-10
# Fraction Deposited in heating:  2.1322354840000667e-11
# Energy is conserved up to (%):  -3.845159006134149e-06
# Fraction Deposited in ICS (Numerical Error):  -3.845158998507189e-08
# Energy conservation with deposited (%):  -7.626958647467452e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  3800558838821.8413
# Fraction of Energy in low energy electrons:  2.7751586490808524e-09
# Fraction of Energy in photons - Continuum:  1.000000030779919
# Fraction Deposited in ionization:  1.0061716449322606e-09
# Fraction Deposited in excitation:  7.701069994300168e-10
# Fraction Deposited in heating:  2.010685419577022e-11
# Energy is conserved up to (%):  -3.5351463257284306e-06
# Fraction Deposited in ICS (Numerical Error):  -3.535146285563304e-08
# Energy conservation with deposited (%):  -4.0165126212580736e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4030310810410.256
# Fraction of Energy in low energy electrons:  2.616957904500551e-09
# Fraction of Energy in photons - Continuum:  1.0000000286927158
# Fraction Deposited in ionization:  9.488138057843656e-10
# Fraction Deposited in excitation:  7.262062657704557e-10
# Fraction Deposited in heating:  1.8960645061996488e-11
# Energy is conserved up to (%):  -3.3003654398024226e-06
# Fraction Deposited in ICS (Numerical Error):  -3.30036542980137e-08
# Energy conservation with deposited (%):  -1.0001053218357965e-14
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4273951783771.138
# Fraction of Energy in low energy electrons:  2.4677755544521335e-09
# Fraction of Energy in photons - Continuum:  1.000000024957671
# Fraction Deposited in ionization:  8.947257086614265e-10
# Fraction Deposited in excitation:  6.848081381348654e-10
# Fraction Deposited in heating:  1.787977615749062e-11
# Energy is conserved up to (%):  -2.902286015650998e-06
# Fraction Deposited in ICS (Numerical Error):  -2.902286007416711e-08
# Energy conservation with deposited (%):  -8.234287315839252e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4532321378990.888
# Fraction of Energy in low energy electrons:  2.327097496172212e-09
# Fraction of Energy in photons - Continuum:  1.0000000227647743
# Fraction Deposited in ionization:  8.437209585898337e-10
# Fraction Deposited in excitation:  6.457699529185069e-10
# Fraction Deposited in heating:  1.6860522173696737e-11
# Energy is conserved up to (%):  -2.659822339614546e-06
# Fraction Deposited in ICS (Numerical Error):  -2.659822343583052e-08
# Energy conservation with deposited (%):  3.968506217461136e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  4806309972999.415
# Fraction of Energy in low energy electrons:  2.1944389338491135e-09
# Fraction of Energy in photons - Continuum:  1.000000021022988
# Fraction Deposited in ionization:  7.956237862313417e-10
# Fraction Deposited in excitation:  6.089571792007913e-10
# Fraction Deposited in heating:  1.5899372077808894e-11
# Energy is conserved up to (%):  -2.4637907223730164e-06
# Fraction Deposited in ICS (Numerical Error):  -2.4637907181593682e-08
# Energy conservation with deposited (%):  -4.2136482870076515e-15
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5096861767930.699
# Fraction of Energy in low energy electrons:  2.0693427079500923e-09
# Fraction of Energy in photons - Continuum:  1.0000000201544215
# Fraction Deposited in ionization:  7.502684421578286e-10
# Fraction Deposited in excitation:  5.742429551332623e-10
# Fraction Deposited in heating:  1.4993014393296486e-11
# Energy is conserved up to (%):  -2.356326842225665e-06
# Fraction Deposited in ICS (Numerical Error):  -2.356326843074468e-08
# Energy conservation with deposited (%):  8.488028030361021e-16
# ***************************************************
# ***************************************************
# rs:  600
# injected energy:  5404978044972.385
# Fraction of Energy in low energy electrons:  1.951377719787003e-09
# Fraction of Energy in photons - Continuum:  1.0000000170159011
# Fraction Deposited in ionization:  7.074986256560655e-10
# Fraction Deposited in excitation:  5.415076507562824e-10
# Fraction Deposited in heating:  1.4138324761986256e-11
# Energy is conserved up to (%):  -2.023042341950324e-06
# Fraction Deposited in ICS (Numerical Error):  -2.023042359730364e-08
# Energy conservation with deposited (%):  1.778004001726482e-14
# ***************************************************

# %% [markdown]
# The output, stored in *elec_cooling_info*, is a tuple containing the following, as well as what each variable is indexed by:
#
# 0. The secondary propagating photon transfer function $\overline{T}_\text{ICS}$ (*eleceng*, *photeng*). This spectrum has the original upscattered CMB photons **already subtracted**, and generically contains negative values at low energies. This spectrum should be viewed as a **distortion** to the CMB spectrum;
# 1. The low-energy electron transfer function $\overline{T}_e$ (*eleceng*, *eleceng*);
# 2. The energy deposited into ionization $\overline{R}_\text{ion}$ (*eleceng*);
# 3. The energy deposited into excitation $\overline{R}_\text{exc}$ (*eleceng*);
# 4. The energy deposited into heating $\overline{R}_\text{heat}$ (*eleceng*);
# 5. The total pre-scattering energy of upscattered CMB photons $\overline{R}_\text{CMB}$ (*eleceng*), and
# 6. Numerical error away from energy conservation (*eleceng*).
#
# These transfer functions are functions of the injected electron energy, and tell us how energy is deposited by a *single* electron with that energy.  For more details, see Section III.D of paper I.
#
# Let's make some plots to understand this. First, let's extract the high-energy deposition into ionization, excitation and heating.

# %% [markdown]
# ## High-Energy Deposition Fractions

# %%
elec_dep_ion  = elec_cooling_info[2]
elec_dep_exc  = elec_cooling_info[3]
elec_dep_heat = elec_cooling_info[4]

# %% [markdown]
# We'll make a plot of the fraction of energy deposited into each of these channels, as a function of the energy injected. These high-energy deposition fractions (for electrons above 3 keV) do *not* include the energy in low-energy electrons, which are processed separately in DarkHistory by [*physics.low_energy*](https://darkhistory.readthedocs.io/en/latest/_autosummary/darkhistory/darkhistory.low_energy.html).

# %%
plt.figure()

plt.loglog()

ion_plot,  = plt.plot(eleceng, elec_dep_ion/eleceng,  label='Ionization')
exc_plot,  = plt.plot(eleceng, elec_dep_exc/eleceng,  label='Excitation')
heat_plot, = plt.plot(eleceng, elec_dep_heat/eleceng, label='Heating')

plt.xlabel('Electron Energy [eV]')
plt.ylabel('Fraction')
plt.title('High-Energy Deposition Fraction')

plt.legend(handles=[ion_plot, exc_plot, heat_plot])

plt.axis([3.2e3, 5e12, 1e-10, 1])
# Out:
# (3200.0, 5000000000000.0, 1e-10, 1.0)

# %% [markdown]
# This plot reflects the fact that for higher energy electrons, atomic processes become less important as channels of energy deposition: instead, most of the energy is instead transferred to CMB photons that undergo inverse Compton scattering (ICS).

# %% [markdown]
# ## Comparing Inverse Compton Scattering and Atomic Processes

# %% [markdown]
# Let's explicitly compare the energy deposited into inverse Compton scattering against the energy deposited via atomic processes plus the low-energy electrons. We will ultimately reproduce the plot shown as Fig. 2 of [[1]](#cite_2015).
#
# Let's add up all the energy in atomic processes plus low-energy electrons. First, we get the low-energy electrons, which is saved as a [*TransFuncAtRedshift*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/transferfunction/darkhistory.spec.transferfunction.TransFuncAtRedshift.html). We can obtain the total energy for each injected electron using `TransFuncAtRedshift.toteng()`. The function `toteng()` sums over the the last axis, i.e. it sums the energy of all photons in each spectrum corresponding to an injected electron. This can then be added to the other components to get the total energy deposited as atomic processes.

# %%
lowengelec_tf = elec_cooling_info[1]

eng_dep_lowengelec = lowengelec_tf.toteng()

eng_dep_atomic = eng_dep_lowengelec + elec_dep_ion + elec_dep_exc + elec_dep_heat

# %% [markdown]
# Now let's look at the energy deposited into ICS. This is equal to the energy stored in the secondary propagating photon spectrum, minus the initial energy of these upscattered photons. Again, we can use `TransFuncAtRedshift.toteng()` to get the total energy in the photon spectrum.

# %%
ICS_phot_tf = elec_cooling_info[0]

eng_dep_ICS_phot = ICS_phot_tf.toteng()

eng_dep_ICS = eng_dep_ICS_phot

# %% [markdown]
# All right, let's make the plot!

# %%
plt.figure()

ax = plt.gca()
ax.set_xscale('log')

atomic_plot, = plt.plot(eleceng, eng_dep_atomic/eleceng,  label='Atomic Processes')
ICS_plot,    = plt.plot(eleceng, eng_dep_ICS/eleceng,  label='Inverse Compton')

plt.xlabel('Electron Energy [eV]')
plt.ylabel('Fraction')
plt.title(r'Deposition Fractions, $z=600$')

plt.legend(handles=[atomic_plot, ICS_plot])

plt.axis([1, 5e12, 0, 1.1])
# Out:
# (1.0, 5000000000000.0, 0.0, 1.1)

# %% [markdown]
# ## Getting Spectra

# %% [markdown]
# The transfer function stored in `ICS_phot_tf` is essentially a list of photon spectra produced by a single electron at some injected energy. Acting this function by matrix multiplication on any arbitrary injection electron spectrum therefore gives the secondary photon spectrum produced after complete cooling of that spectrum. Again, we emphasize that `ICS_phot_tf` has the pre-scattering spectrum of upscattered CMB photons **subtracted** from the spectrum.
#
# Let's take some electron spectrum, produced by annihilation of dark matter into a $\tau^+ \tau^-$ pair. This can be obtained from [*darkhistory.spec.pppc*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/darkhistory.spec.pppc.html), which returns the same flux produced by PPPC4DMID [[2]](#cite_PPPC). We'll pick $m_\text{DM}$ = 50 GeV, and obtain the spectrum per annihilation.

# %%
from darkhistory.spec.pppc import get_pppc_spec

mDM = 50e9

elec_spec = get_pppc_spec(mDM, eleceng, 'tau', 'elec')
# Out:
# ../config.py:389: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   coords_data = np.array(json.load(data_file))
# ../config.py:391: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values_data = np.array(json.load(data_file))

# %% [markdown]
# `elec_spec` here is a [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object, and contains the abscissa (`eleceng`) and the spectrum, stored as dN/dE or N. To contract this spectrum with `ICS_phot_tf`, we use the `TransferFuncAtRedshift.sum_specs`, which acts with the matrix stored in `ICS_phot_tf` on the spectrum.

# %%
phot_spec = ICS_phot_tf.sum_specs(elec_spec.N)

# %% [markdown]
# This produces a photon [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object, with the abscissa given by `photeng`.
#
# We can also produce the initial spectrum of photons that got scattered. This is a blackbody spectrum, since we are only tracking photons that get upscattered in the nonrelativistic, Thomson regime (see section III.D of paper I for more details). The CMB spectrum at any temperature can be obtained using [*physics.CMB_spec()*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/physics/darkhistory.physics.CMB_spec.html). This returns a spectrum containing $dN/(dE\, dV)$ of the CMB.
#
# We simply have to rescale this spectrum to the total energy of CMB photons upscattered, which is stored in the output above.

# %%
eng_initial_cmb = elec_cooling_info[5]

# %% [markdown]
# First, let's put the spectrum in a [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object.

# %%
from darkhistory.spec.spectrum import Spectrum

# Use physics.TCMB() to get the temperature at the right redshift.
CMB_spec = Spectrum(photeng, phys.CMB_spec(photeng, phys.TCMB(rs)), spec_type='dNdE')

# %% [markdown]
# Now, we want to rescale this spectrum so that it has the initial energy of the photons that got upscattered. This energy is given by `np.dot(eng_initial_cmb, elec_spec.N)`, since `eng_initial_cmb` has each bin normalized to one injected electron at some energy.
#
# We can do the rescaling simply by multiplying the [*Spectrum*](https://darkhistory.readthedocs.io/en/master/_autosummary/darkhistory/spec/spectrum/darkhistory.spec.spectrum.Spectrum.html) object itself.

# %%
CMB_spec *= np.dot(eng_initial_cmb, elec_spec.N)/CMB_spec.toteng()

# %% [markdown]
# Here are the produced spectra. To recap, `elec_spec` contains the injected electron spectrum. `phot_spec` contains the secondary photon spectrum produced with the initial upscattered CMB spectrum subtracted. `CMB_spec` is that initial upscattered CMB spectrum, and `phot_spec + CMB_spec` gives the final spectrum of all photons upscattered by ICS.

# %%
plt.figure()

plt.loglog()

elec_spec_plot, = plt.plot(eleceng, elec_spec.dNdE*eleceng**2, label=r'Injected $e^+e^-$ Spectrum')
phot_spec_plot, = plt.plot(photeng, phot_spec.dNdE*photeng**2, label='ICS Secondary Photon Spectrum')
CMB_plot,       = plt.plot(photeng, CMB_spec.dNdE*photeng**2,  'k--', label='Upscattered CMB')
combined_plot,  = plt.plot(photeng, (phot_spec.dNdE + CMB_spec.dNdE)*photeng**2, label='ICS Scattered Photon Spectrum')

plt.xlabel('Energy [eV]')
plt.ylabel(r'$E^2\, dN/dE$ [eV]')
plt.title('ICS Spectra')

plt.text(0.1, 0.92, r'$\chi \chi \to \tau^+\tau^-$, $m_\chi$ = 50 GeV', fontsize=20, transform=ax.transAxes) 

plt.legend(handles=[elec_spec_plot, phot_spec_plot, CMB_plot, combined_plot], loc=(0.1, 0.58))

plt.axis([1e-4, 1e12, 1e-10, 1e25])
# Out:
# (0.0001, 1000000000000.0, 1e-10, 1e+25)

# %% [markdown]
# The black dashed line shows the spectrum of photons that got upscattered as the electron spectrum (blue) cools completely, producing the final photon spectrum shown in orange.

# %% [markdown]
# ## Bibliography

# %% [markdown]
# [1]<a id='cite_2015'></a> T. Slatyer, "Indirect Dark Matter Signatures in the Cosmic Dark Ages II. Ionization, Heating and Photon Production from Arbitrary Energy Injections," arXiv:1506.03812, Phys. Rev. D93, 023521 (2016).
#
# [2]<a id='cite_PPPC'></a> M.Cirelli, G.Corcella, A.Hektor, G.Hütsi, M.Kadastik, P.Panci, M.Raidal, F.Sala, A.Strumia, "PPPC 4 DM ID: A Poor Particle Physicist Cookbook for Dark Matter Indirect Detection," arXiv 1012.4515, JCAP 1103 (2011) 051. Erratum: JCAP 1210 (2012) E01.
